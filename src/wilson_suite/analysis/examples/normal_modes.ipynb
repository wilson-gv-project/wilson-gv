# %%
from wilson_suite.wilson_analysis.analysis.normal_modes_analysis import show_mode, make_normal_mode_str
import wilson_suite as ws
from wilson_suite.wilson_utils.serialization import unpickle_smth_from

unpickled = unpickle_smth_from(ws.wilson_utils.paths.SUITE_ROOT+'/../data_for_tests/FORM_conf1_B3LYP_aug_cc_pVTZ.pkl')

# %%
unpickled['atoms']
# Out:
# ['O', 'C', 'H', 'H']

# %%
unpickled['normal_modes']
# Out:
# {0: array([ 0.04, -0.  , -0.  , -0.17,  0.  ,  0.  ,  0.7 , -0.  , -0.  ,
#          0.7 , -0.  ,  0.  ]),
#  1: array([ 0.  ,  0.08,  0.  , -0.  , -0.15, -0.  ,  0.  ,  0.25,  0.65,
#          0.  ,  0.25, -0.65]),
#  2: array([-0.  ,  0.  , -0.08,  0.  , -0.  ,  0.  , -0.  ,  0.35,  0.61,
#         -0.  , -0.35,  0.61]),
#  3: array([-0.  ,  0.  , -0.42,  0.  , -0.  ,  0.59, -0.  , -0.44, -0.22,
#         -0.  ,  0.44, -0.22]),
#  4: array([ 0.  ,  0.  ,  0.  , -0.  , -0.  ,  0.06,  0.  ,  0.61, -0.35,
#          0.  , -0.61, -0.35]),
#  5: array([-0.  ,  0.  ,  0.  ,  0.  , -0.1 , -0.  , -0.  ,  0.6 , -0.37,
#         -0.  ,  0.6 ,  0.37])}

# %%
unpickled['equilibrium_geometry']
# Out:
# array([[-0.      ,  0.      ,  0.673271],
#        [ 0.      ,  0.      , -0.52697 ],
#        [ 0.      ,  0.938294, -1.112173],
#        [-0.      , -0.938294, -1.112173]])

# %%
make_normal_mode_str(unpickled['atoms'], unpickled['equilibrium_geometry'], 
                normal_mode=unpickled['normal_modes'][1])
# Out:
# '4\n\nO      -0.0000000       0.0000000       0.6732710       0.0000000       0.0800000       0.0000000\nC       0.0000000       0.0000000      -0.5269700      -0.0000000      -0.1500000      -0.0000000\nH       0.0000000       0.9382940      -1.1121730       0.0000000       0.2500000       0.6500000\nH      -0.0000000      -0.9382940      -1.1121730       0.0000000       0.2500000      -0.6500000\n'

# %%
for i in [0, 1, 2, 3, 4, 5]:
    print(i)
    show_mode(i,unpickled['atoms'],unpickled['equilibrium_geometry'],unpickled['normal_modes'])
# Out:
# 0
# <div id="3dmolviewer_17726677565122895"  style="position: relative; width: 600px; height: 300px;">
#         <p id="3dmolwarning_17726677565122895" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...

# %% [markdown]
# #### Intro

# %%
###########################################################
##                                                       ##
##    Tests : 2DIR spectra calculation examples          ##
##                                                       ##
###########################################################

import os
import sys

# project_root = os.path.abspath(os.path.dirname(__file__))
# sys.path.append(project_root[:-7])
# print(project_root[:-7])

import main2DIR as dd_ir
import numpy as np


# Terms in expressions
electrical_terms = [('a+b,a', 'zero,a'), ('b,a', 'zero,a') ]

# derivatives:
# 1. mu_Q, mu QQ, alpha_Q - electric dipole (1st and 2nd derivatives), polarizability (1st der.)
# 2. mu_Q, alpha_QQ - electric dipole (1st der.), polarizability (2nd der.)
electric_avrg = [[('mu_Q', ('a',)), ('alpha_Q', ('b',)), ('mu_QQ', ('a', 'b',))],
                 [('mu_Q', ('a',)), ('alpha_QQ', ('a', 'b',)), ('mu_Q', ('b',))] ]

mechanical_terms = [[('a+b,a', 'zero,a'), ('a+b+c,zero', 'c,a+b')],
                    [('c,a', 'zero,a'), ('a+b,c', 'b+c,a')],
                    [('a+b,a', 'zero,a'), ('a,a+b', 'b,zero')],
                    [('b,a', 'zero,a'), ('b,a+b', 'a,zero')],
                    [('b,a', 'zero,a'), ('a,a+b', 'b,zero')],
                    [('b,a', 'zero,a'), ('b,a+b', 'a,zero')] ]

# derivatives:
# mu_Q, alpha_Q - for all 6 terms
mechanical_avrg = [[('mu_Q', ('a',)), ('alpha_Q', ('b',)), ('mu_Q', ('c',)), 'abc'],
                   [('mu_Q', ('a',)), ('alpha_Q', ('b',)), ('mu_Q', ('c',)), 'abc'],
                   [('mu_Q', ('a',)), ('alpha_Q', ('b',)), ('mu_Q', ('a',)), 'bcc'],
                   [('mu_Q', ('a',)), ('alpha_Q', ('b',)), ('mu_Q', ('b',)), 'acc'],
                   [('mu_Q', ('a',)), ('alpha_Q', ('a',)), ('mu_Q', ('b',)), 'bcc'],
                   [('mu_Q', ('a',)), ('alpha_Q', ('b',)), ('mu_Q', ('b',)), 'acc'] ]


def picks(pool, listofinds):
    return [pool[i] for i in listofinds]


printDerivs = False

test1 = False
test11 = False
ee1, mm1 = [1], []

test22 = False
test222 = True
# ee1, mm1 = [0, 1], [0]

test2 = False
waterBool = False
acetonitrileBool = False

w1mw2 = False

np.set_printoptions(suppress=True, linewidth=150)

# %% [markdown]
# #### test222

# %%
import matplotlib.pyplot as plt
# %matplotlib ipympl

def test222():
    import time
    c0 = time.process_time()

    funds = dict(zip(['0', '1'], [858., 2309.]))

    delta = {'00': 1713.15, '01': 3162.61, '11': 4615.27, 
             '000': 2572.5, '001': 4020.1, '011': 5470.7, '110': 5470.7, '111': 6927.}

    # set up frequencies for x and y axes: # todo 1 (starting point for rendering)
    w1, w2 = np.linspace(650.2, 3427.3, 350), np.linspace(1250.2, 4892.6, 350)
    
    # w1 = [792., 792., 792., 2360.]
    # w2 = [1701., 2300., 3169.61, 3169.61]

    # create class instance: initialize a 2dir spectrum instance
    h = dd_ir.SpectrumEVV(w1, w2, funds, Gamma=100., avrg_ones=True, Delta=delta, margin=78.)  # gamma 0.9931160484209338 = 10 ** (-0.003)

    # get derivatives - mu_Q, mu QQ, alpha_Q, alphaQQ, F_abc
    # todo: setup PyOpenrsp calculations (should be more flexible)
    derivData = h.getDerivs()
    print(derivData) if printDerivs else None

    # selection of terms by index in the complete list
    ee, mm = ee1, mm1
    # ee, mm = [0, 1], [0, 1]
    # ee, mm = [0, 1], [0, 1, 2, 3, 4, 5]

    # add mechanical and electrical anharmonicities terms and orientational averages (symbolic setup)
    h.addTerms(picks(electrical_terms, ee), picks(mechanical_terms, mm),
               picks(electric_avrg, ee), picks(mechanical_avrg, mm))

    # plot (and save plot) 2D spectrum
    mech = 'mechNone' if not picks(mechanical_terms, mm) else f'mech{len(picks(mechanical_terms, mm))}'
    elec = 'elecNone' if not picks(electrical_terms, ee) else f'elec{len(picks(electrical_terms, ee))}'
    test222_name = f'test222_{mech}_{mm}_{elec}_{ee}' if h.coords_abc is not None else f'test1_{elec}_{ee}'
    
    if w1mw2: test222_name+='_w1mw2'

    # print(h.totInt())

    c1 = time.process_time()
    print('before h.plot2D', c1-c0)

    z, f = h.plot2D(figname=test222_name, w1mw2=w1mw2, style='contour')

# %%
import matplotlib.pyplot as plt
# %matplotlib ipympl

def test222():
    import time
    c0 = time.process_time()

    funds = dict(zip(['0', '1'], [858., 2309.]))

    delta = {'00': 1713.15, '01': 3162.61, '11': 4615.27, 
             '000': 65.0, '001': 90.0, '011': 105.0, '110': 105.0, '111': 120.0}

    # set up frequencies for x and y axes: # todo 1 (starting point for rendering)
    w1, w2 = np.linspace(650.2, 3427.3, 350), np.linspace(1250.2, 4892.6, 350)
    
    # w1 = [792., 792., 792., 2360.]
    # w2 = [1701., 2300., 3169.61, 3169.61]

    # create class instance: initialize a 2dir spectrum instance
    h = dd_ir.SpectrumEVV(w1, w2, funds, Gamma=100., avrg_ones=True, Delta=delta, margin=78.)  # gamma 0.9931160484209338 = 10 ** (-0.003)

    # get derivatives - mu_Q, mu QQ, alpha_Q, alphaQQ, F_abc
    # todo: setup PyOpenrsp calculations (should be more flexible)
    derivData = h.getDerivs()
    print(derivData) if printDerivs else None

    # selection of terms by index in the complete list
    ee, mm = ee1, mm1
    # ee, mm = [0, 1], [0, 1]
    # ee, mm = [0, 1], [0, 1, 2, 3, 4, 5]

    # add mechanical and electrical anharmonicities terms and orientational averages (symbolic setup)
    h.addTerms(picks(electrical_terms, ee), picks(mechanical_terms, mm),
               picks(electric_avrg, ee), picks(mechanical_avrg, mm))

    # plot (and save plot) 2D spectrum
    mech = 'mechNone' if not picks(mechanical_terms, mm) else f'mech{len(picks(mechanical_terms, mm))}'
    elec = 'elecNone' if not picks(electrical_terms, ee) else f'elec{len(picks(electrical_terms, ee))}'
    test222_name = f'test222_{mech}_{mm}_{elec}_{ee}' if h.coords_abc is not None else f'test1_{elec}_{ee}'
    
    if w1mw2: test222_name+='_w1mw2'

    # print(h.totInt())

    c1 = time.process_time()
    print('before h.plot2D', c1-c0)

    z, f = h.plot2D(figname=test222_name, w1mw2=w1mw2, style='contour')

# %% [markdown]
# #### test222 runs

# %% [markdown]
# ##### 1

# %%
printDerivs = False

ee1, mm1 = [], [0]

w1mw2 = False

test222()
# Out:
# [] electrical_terms
# [['a+b', 'a'], ['zero', 'a']]
# [[('a+b,a', 'zero,a'), ('a+b+c,zero', 'c,a+b')]] mechanical_terms
# before h.plot2D 0.0
# w1, w2, margin ('a+b+c,zero', 'c,a+b')
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[4], line 7
#       3 ee1, mm1 = [], [0]
#       5 w1mw2 = False
# ----> 7 test222()
#
# Cell In[3], line 48, in test222()
#      45 c1 = time.process_time()
#      46 print('before h.plot2D', c1-c0)
# ---> 48 z, f = h.plot2D(figname=test222_name, w1mw2=w1mw2, style='contour')
#
# File ~/mock2D/main2DIR.py:296, in SpectrumEVV.plot2D(self, figname, w1mw2, style)
#     294 ax.format_coord = custom_format_coord
#     295 # points
# --> 296 Z = self.totInt(style)
#     297 print('Z are calculated')
#     299 if style == 'surface' or style == 'contour':
#
# File ~/mock2D/main2DIR.py:261, in SpectrumEVV.totInt(self, style)
#     255     Z += contrib_ab
#     257 for i in Qabc:
#     258     # print(i)
#     259     # print('Z here again', Z)
#     260     # print('gamma_mn', self.gamma_mn(style, i[0], i[1]))
# --> 261     contrib_abc = self.gamma_mn(style, i[0], i[1], i[2])
#     262     Qabc_contrib_dict[tuple(i)] = contrib_abc
#     263     Z += contrib_abc
#
# File ~/mock2D/main2DIR.py:221, in SpectrumEVV.gamma_mn(self, style, a, b, c, molfile, rspfile)
#     218 # print(F)
#     220 if style == 'surface' or style == 'contour':
# --> 221     total_sum_mech += prefac_mech * averg_mech1 * F * mech_func(self.all_states,
#     222                                                                 self.w1_mesh, self.w2_mesh, self.Gamma,
#     223                                                                 (a, b, c))
#     224 else:
#     225     total_sum_mech = []
#
# File ~/mock2D/main2DIR.py:487, in w_mn_prod.<locals>.function(w_all, w1, w2, Gamma, abctuple, m1n1m2n2, fermi)
#     485     print('w1, w2, margin', margin)
#     486     # removes lower diagonal with margin 4
# --> 487     return np.where(w2-margin > w1, 1 / (w_all[wm1] - w_all[wn1] + w1 - w2 - 1j * Gamma) / (w_all[wm2] - w_all[wn2] + w1 - 1j * Gamma), 0.)
#     489 else:
#     490     w_fr1 = ''.join(sorted([str(dictabc[i]) for i in fermi[0][0].split('+')]))
#
# UFuncTypeError: ufunc 'subtract' did not contain a loop with signature matching types (dtype('float64'), dtype('<U10')) -> None
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ##### 2

# %%
printDerivs = False

ee1, mm1 = [1], []

w1mw2 = False

test222()

# %% [markdown]
# ##### 3

# %%
printDerivs = False

ee1, mm1 = [0, 1], []

w1mw2 = False
# plt.title('hfify')
test222()

# %% [markdown]
# #### Test1

# %%
###    Test 1
if test1:
    # todo 3 + todo 2: should be coming from SpectroscPy
    # funds = dict(zip(['0', '1', '2'], [25., 40., 85.]))
    funds = dict(zip(['0', '1'], [25., 40.]))
    delta = {'00': 47.0, '01': 57., '11': 77., '000': 65.0, '001': 90.0, '011': 105.0, '110': 105.0, '111': 120.0}
    # set up frequencies for x and y axes: # todo 1 (starting point for rendering)
    # w1, w2 = np.arange(0., 110, 1.), np.arange(0, 110, 1.)

    a = list(funds.values())
    import itertools
    template_w = list(set([i[0]+i[1] for i in list(itertools.product(a, a))]))
    template_w.append(0.)
    template_w.append(max(template_w)+5.)
    template_w = sorted(template_w+[25., 40.])
    w1, w2 = [25.]*len(template_w), template_w.copy()
    w1 = [25., 25., 25., 40., 40., 40.]
    w2 = [40., 47., 57., 25., 57., 77.]

    w1 = [25., 25., 40., 40.]
    w2 = [47., 57., 57., 77.]

    print('w1', w1)
    print('w2', w2)

    # print(w1)
    # create class instance: initialize a 2dir spectrum instance
    # h = dd_ir.SpectrumEVV(w1, w2, funds, Gamma=10 ** (-0.003), avrg_ones=True)  # gamma 0.9931160484209338
    h = dd_ir.SpectrumEVV(w1, w2, funds, Gamma=0.00000001, avrg_ones=True, Delta=delta)  # gamma 0.9931160484209338
    h = dd_ir.SpectrumEVV(w1, w2, funds, Gamma=10 ** (-0.003), avrg_ones=True, Delta=delta)  # gamma 0.9931160484209338
    h = dd_ir.SpectrumEVV(w1, w2, funds, Gamma=1., avrg_ones=True, Delta=delta)  # gamma 0.9931160484209338

    # get derivatives - mu_Q, mu QQ, alpha_Q, alphaQQ, F_abc
    # todo: setup PyOpenrsp calculations (should be more flexible)
    derivData = h.getDerivs()
    print(derivData) if printDerivs else None

    # selection of terms by index in the complete list
    ee, mm = ee1, mm1
    # ee, mm = [0, 1], [0, 1]
    # ee, mm = [0, 1], [0, 1, 2, 3, 4, 5]

    # add mechanical and electrical anharmonicities terms and orientational averages (symbolic setup)
    h.addTerms(picks(electrical_terms, ee), picks(mechanical_terms, mm),
               picks(electric_avrg, ee), picks(mechanical_avrg, mm))

    # plot (and save plot) 2D spectrum
    mech = 'mechNone' if not picks(mechanical_terms, mm) else f'mech{len(picks(mechanical_terms, mm))}'
    elec = 'elecNone' if not picks(electrical_terms, ee) else f'elec{len(picks(electrical_terms, ee))}'
    test1_name = f'test1_{mech}_{mm}_{elec}_{ee}' if h.coords_abc is not None else f'test1_{elec}_{ee}'
    if w1mw2: test1_name += '_w1mw2'

    print(h.totInt(style='scatter'))
    h.plot2D(figname=test1_name, w1mw2=w1mw2, style='scatter')

# %%
# %matplotlib inline

def funplot():
    import matplotlib.pyplot as plt
    fig, ax = plt.subplots()
    ax.scatter([1, 2, 3, 4, 5, 6], [1, 2, 3])
    plt.show()
    
funplot()
print("geihjrlfherlf")

# %%
from testmain import funplot
funplot()

# %%
openrsp = """
BASIS
STO-3G
Carbon monoxide
Linear
AtomTypes=2 Nosymmetry Units=Angstrom
Charge=6.0 Atoms=1
C   0.0000  0.0000  -0.6434
Charge=8.0 Atoms=1
O   0.0000  0.0000  0.4825

"""

# %%
t = {'a':1, 'b':2}
t|{'b':-1}
# Out:
# {'a': 1, 'b': -1}

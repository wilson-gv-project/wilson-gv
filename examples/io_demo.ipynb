# %%
# save EVV experiment - the instance is all set
# save derived terms from evv experiment

# %%
from wilson_suite.wilson_utils.serialization import unpickle_smth_from
# Source - https://stackoverflow.com/a
# Posted by pycruft, modified by community. See post 'Timeline' for change history
# Retrieved 2026-01-17, License - CC BY-SA 4.0

from os import listdir
from os.path import isfile, join
wsim_dir = '/home/vlev/workflows/run_2026-01-17_17-43-48/'

onlyfiles = [f for f in listdir(wsim_dir) if isfile(join(wsim_dir, f))]

things = []
for f in onlyfiles:
    print(join(wsim_dir, f))
    things.append(unpickle_smth_from(join(wsim_dir, f)))
# Out:
# /home/vlev/workflows/run_2026-01-17_17-43-48/data_file.pkl
# /home/vlev/workflows/run_2026-01-17_17-43-48/WilsonSimulation_instance.pkl
# /home/vlev/workflows/run_2026-01-17_17-43-48/EvaluationInputs.pkl

# %%
for t in things:
    print(type(t))
# Out:
# <class 'dict'>
# <class 'wilson_suite.wilson_main.workflow_abstractions.WilsonSimulation'>
# <class 'wilson_suite.wilson_intensities.amplitudes.evaluation_wf.EvaluationInputs'>

# %%
print(things[1].exp)
# Out:
# VibExperiment(field=ElectricField(pulses=(EmPulse(env='gaussian', tc=50.0, cf=0.0, dev=0.0, cf_uv=0.0, maxstr=1e-05, wv=(0.0, 0.0, 1.0), pol=(1.0, 0.0, 0.0), overall_phase=(1+0j), id=1), EmPulse(env='gaussian', tc=100.0, cf=0.0, dev=0.0, cf_uv=0.0, maxstr=1e-05, wv=(0.0, 0.0, 1.0), pol=(1.0, 0.0, 0.0), overall_phase=(1+0j), id=2), EmPulse(env='gaussian', tc=120.0, cf=0.0, dev=0.0, cf_uv=0.072, maxstr=1e-05, wv=(0.0, 0.0, 1.0), pol=(1.0, 0.0, 0.0), overall_phase=(1+0j), id=3))), detector=SpecDetector(detection_method='freq', detector_location=(0.0, 0.0, 1.0), detection_polarization=(1.0, 0.0, 0.0), detection_range=[0.003, 0.0031, 0.0032, 0.0033, 0.0034000000000000002, 0.0035, 0.0036, 0.0037, 0.0038, 0.0039000000000000003, 0.004, 0.0041, 0.004200000000000001, 0.0043, 0.0044, 0.0045000000000000005, 0.0046, 0.0047, 0.0048000000000000004, 0.0049, 0.005, 0.0051, 0.0052, 0.0053, 0.0054, 0.0055, 0.005600000000000001, 0.0057, 0.0058, 0.005900000000000001, 0.006, 0.0061, 0.006200000000000001, 0.0063, 0.0064, 0.006500000000000001, 0.0066, 0.0067, 0.0068000000000000005, 0.0069, 0.007, 0.0071, 0.007200000000000001, 